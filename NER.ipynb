# %% [markdown]
# <a href="https://colab.research.google.com/github/faiyazansariusa/ColabAI/blob/main/NER.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Named Entity Recognition (NER)
from transformers import pipeline

ner=pipeline("ner")
# Out:
# No model was supplied, defaulted to dbmdz/bert-large-cased-finetuned-conll03-english and revision 4c53496 (https://huggingface.co/dbmdz/bert-large-cased-finetuned-conll03-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Some weights of the model checkpoint at dbmdz/bert-large-cased-finetuned-conll03-english were not used when initializing BertForTokenClassification: ['bert.pooler.dense.bias', 'bert.pooler.dense.weight']
# - This IS expected if you are initializing BertForTokenClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForTokenClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
ner("Mahatma Gandhi is Father of India")
# Out:
# [{'entity': 'I-PER',
#   'score': np.float32(0.9984652),
#   'index': 1,
#   'word': 'Ma',
#   'start': 0,
#   'end': 2},
#  {'entity': 'I-PER',
#   'score': np.float32(0.9911345),
#   'index': 2,
#   'word': '##hat',
#   'start': 2,
#   'end': 5},
#  {'entity': 'I-PER',
#   'score': np.float32(0.9502723),
#   'index': 3,
#   'word': '##ma',
#   'start': 5,
#   'end': 7},
#  {'entity': 'I-PER',
#   'score': np.float32(0.99758863),
#   'index': 4,
#   'word': 'Gandhi',
#   'start': 8,
#   'end': 14},
#  {'entity': 'I-MISC',
#   'score': np.float32(0.6881907),
#   'index': 8,
#   'word': 'India',
#   'start': 28,
#   'end': 33}]

# %%
ner("I am working as AI Professional in Synechron Technologies PVT LTD")
# Out:
# [{'entity': 'I-ORG',
#   'score': np.float32(0.99917233),
#   'index': 8,
#   'word': 'S',
#   'start': 35,
#   'end': 36},
#  {'entity': 'I-ORG',
#   'score': np.float32(0.97441477),
#   'index': 9,
#   'word': '##yne',
#   'start': 36,
#   'end': 39},
#  {'entity': 'I-ORG',
#   'score': np.float32(0.98443764),
#   'index': 10,
#   'word': '##ch',
#   'start': 39,
#   'end': 41},
#  {'entity': 'I-ORG',
#   'score': np.float32(0.9932862),
#   'index': 11,
#   'word': '##ron',
#   'start': 41,
#   'end': 44},
#  {'entity': 'I-ORG',
#   'score': np.float32(0.9964463),
#   'index': 12,
#   'word': 'Technologies',
#   'start': 45,
#   'end': 57},
#  {'entity': 'I-ORG',
#   'score': np.float32(0.9298065),
#   'index': 13,
#   'word': 'P',
#   'start': 58,
#   'end': 59},
#  {'entity': 'I-ORG',
#   'score': np.float32(0.56313735),
#   'index': 14,
#   'word': '##V',
#   'start': 59,
#   'end': 60},
#  {'entity': 'I-ORG',
#   'score': np.float32(0.53255725),
#   'index': 15,
# ...

# %%
ner("I Love India")
# Out:
# [{'entity': 'I-MISC',
#   'score': np.float32(0.8863509),
#   'index': 1,
#   'word': 'I',
#   'start': 0,
#   'end': 1},
#  {'entity': 'I-MISC',
#   'score': np.float32(0.7492202),
#   'index': 2,
#   'word': 'Love',
#   'start': 2,
#   'end': 6},
#  {'entity': 'I-MISC',
#   'score': np.float32(0.43893844),
#   'index': 3,
#   'word': 'India',
#   'start': 7,
#   'end': 12}]

# %%
ner("I Like Orange")
# Out:
# [{'entity': 'I-MISC',
#   'score': np.float32(0.4007005),
#   'index': 1,
#   'word': 'I',
#   'start': 0,
#   'end': 1},
#  {'entity': 'I-MISC',
#   'score': np.float32(0.48351255),
#   'index': 2,
#   'word': 'Like',
#   'start': 2,
#   'end': 6},
#  {'entity': 'I-ORG',
#   'score': np.float32(0.574686),
#   'index': 3,
#   'word': 'Orange',
#   'start': 7,
#   'end': 13}]

# %%
ner("I Live in Pune")
# Out:
# [{'entity': 'I-LOC',
#   'score': np.float32(0.99471396),
#   'index': 4,
#   'word': 'Pune',
#   'start': 10,
#   'end': 14}]

# %%
#Text Summarization
summarizer=pipeline("summarization")
# Out:
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# config.json: 0.00B [00:00, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/1.22G [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json: 0.00B [00:00, ?B/s]
# merges.txt: 0.00B [00:00, ?B/s]
# Device set to use cpu

# %%
text =""" Bhanu Vohra, Citigroup Inc’s head of commercial banking in India, is set to leave the firm after about two-and-a-half decades with the bank, Bloomberg reported.

Vohra is currently on gardening leave and “exploring other career opportunities", according to the report. He tendered his resignation a few weeks ago. Most recently, the veteran banker led a team delivering global banking solutions to Indian mid-sized firms.

He joined Citi in 2000 and has served in various leadership roles across operations, transaction banking, and global markets.

During his career, Vohra worked in both the Asia-Pacific and EMEA (Europe, Middle East and Africa) regions. He returned to India to head Citi’s Global Subsidiaries Group within the Banking, Capital Markets and Advisory (BCMA) vertical. He also held senior roles in Citi’s Treasury and Trade Services (TTS) and its Operations and Technology division."""

# %%
summarizer(text,max_length=56)
# Out:
# [{'summary_text': " Bhanu Vohra, Citigroup's head of commercial banking in India, is set to leave the firm . He joined Citi in 2000 and has served in various leadership roles across operations, transaction banking, and global markets . He is currently on gardening leave"}]

# %%
#Assessment1
#summarize the doc with model

# %%
# prompt: read the content from pdf file for summarization

# !pip install PyMuPDF
import fitz

def read_pdf(filepath):
  """Reads text content from a PDF file."""
  doc = fitz.open(filepath)
  text = ""
  for page_num in range(doc.page_count):
    page = doc.load_page(page_num)
    text += page.get_text()
  return text

# Replace 'your_pdf_file.pdf' with the actual path to your PDF file
pdf_text = read_pdf('/content/Intro to Docker Study Guide.pdf')

# Now you can use the summarizer pipeline with the extracted text
from transformers import pipeline
summarizer = pipeline("summarization")

# You can adjust the max_length as needed
summary = summarizer(pdf_text, max_length=150, min_length=30, do_sample=False)
print(summary[0]['summary_text'])
# Out:
# ...
# No model was supplied, defaulted to sshleifer/distilbart-cnn-12-6 and revision a4f8f3e (https://huggingface.co/sshleifer/distilbart-cnn-12-6).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use cpu
#  The Docker Engine is a software program that runs on various operating systems (Linux, Windows Server) and provides the underlying runtime environment for your Docker containers . By understanding these core concepts, you can leverage Docker to stream your application and deployment processes . The next chapter will explore how Docker integrates with ubernetes for container orchestration .
