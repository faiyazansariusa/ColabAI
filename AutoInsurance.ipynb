# %% [markdown]
# <a href="https://colab.research.google.com/github/faiyazansariusa/ColabAI/blob/main/AutoInsurance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# prompt: import numpy pandas ,matplotlib,seaborn,and all ml packages for regression

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
from sklearn.neural_network import MLPRegressor

# %%
df=pd.read_csv("/content/AutoInsurance.csv")

# %%
df.head()
# Out:
#   Customer       State  Customer Lifetime Value Response  Coverage Education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
# 2  AI49188      Nevada             12887.431650       No   Premium  Bachelor
# 3  WW63253  California              7645.861827       No     Basic  Bachelor
# 4  HB64268  Washington              2813.692575       No     Basic  Bachelor
#
#   Effective To Date EmploymentStatus Gender  Income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# 1           1/31/11       Unemployed      F       0  ...
# 2           2/19/11         Employed      F   48767  ...
# 3           1/20/11       Unemployed      M       0  ...
# 4          3/2/2011         Employed      M   43836  ...
#
#   Months Since Policy Inception Number of Open Complaints  Number of Policies  \
# ...

# %%
# prompt: Drop Customer,Effective To Date

df = df.drop(['Customer', 'Effective To Date'], axis=1)
df.head()
# Out:
#         State  Customer Lifetime Value Response  Coverage Education  \
# 0  Washington              2763.519279       No     Basic  Bachelor
# 1     Arizona              6979.535903       No  Extended  Bachelor
# 2      Nevada             12887.431650       No   Premium  Bachelor
# 3  California              7645.861827       No     Basic  Bachelor
# 4  Washington              2813.692575       No     Basic  Bachelor
#
#   EmploymentStatus Gender  Income Location Code Marital Status  ...  \
# 0         Employed      F   56274      Suburban        Married  ...
# 1       Unemployed      F       0      Suburban         Single  ...
# 2         Employed      F   48767      Suburban        Married  ...
# 3       Unemployed      M       0      Suburban        Married  ...
# 4         Employed      M   43836         Rural         Single  ...
#
#    Months Since Policy Inception  Number of Open Complaints  \
# 0                              5                          0
# ...

# %%
df.isnull().sum()
# Out:
# State                            0
# Customer Lifetime Value          0
# Response                         0
# Coverage                         0
# Education                        0
# EmploymentStatus                 0
# Gender                           0
# Income                           0
# Location Code                    0
# Marital Status                   0
# Monthly Premium Auto             0
# Months Since Last Claim          0
# Months Since Policy Inception    0
# Number of Open Complaints        0
# Number of Policies               0
# Policy Type                      0
# Policy                           0
# Renew Offer Type                 0
# Sales Channel                    0
# Total Claim Amount               0
# Vehicle Class                    0
# Vehicle Size                     0
# dtype: int64

# %%
# prompt: Label Encoding for all categorical columns using for loop

from sklearn.preprocessing import LabelEncoder

# Create a LabelEncoder object
le = LabelEncoder()

# Iterate over each column in the DataFrame
for col in df.columns:
    # Check if the column has object data type (categorical)
    if df[col].dtype == 'object':
        # Apply Label Encoding to the column
        df[col] = le.fit_transform(df[col])

df.head()
# Out:
#    State  Customer Lifetime Value  Response  Coverage  Education  \
# 0      4              2763.519279         0         0          0
# 1      0              6979.535903         0         1          0
# 2      2             12887.431650         0         2          0
# 3      1              7645.861827         0         0          0
# 4      4              2813.692575         0         0          0
#
#    EmploymentStatus  Gender  Income  Location Code  Marital Status  ...  \
# 0                 1       0   56274              1               1  ...
# 1                 4       0       0              1               2  ...
# 2                 1       0   48767              1               1  ...
# 3                 4       1       0              1               1  ...
# 4                 1       1   43836              0               2  ...
#
#    Months Since Policy Inception  Number of Open Complaints  \
# 0                              5                          0
# ...

# %%
df.dtypes
# Out:
# State                              int64
# Customer Lifetime Value          float64
# Response                           int64
# Coverage                           int64
# Education                          int64
# EmploymentStatus                   int64
# Gender                             int64
# Income                             int64
# Location Code                      int64
# Marital Status                     int64
# Monthly Premium Auto               int64
# Months Since Last Claim            int64
# Months Since Policy Inception      int64
# Number of Open Complaints          int64
# Number of Policies                 int64
# Policy Type                        int64
# Policy                             int64
# Renew Offer Type                   int64
# Sales Channel                      int64
# Total Claim Amount               float64
# Vehicle Class                      int64
# Vehicle Size                       int64
# dtype: object

# %%
Y=df[["Customer Lifetime Value"]]
X=df.drop("Customer Lifetime Value",axis=1)

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,)

# %%
model_lr=LinearRegression()
model_lr.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
# prompt: get the score of the model

score = model_lr.score(X_test, Y_test)
print(f"Model Score: {score}")
# Out:
# Model Score: 0.15248050092015653

# %%
# prompt: try with KNN SVR DTR Bagging Regressor, RFR

from sklearn.ensemble import BaggingRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor

# KNN Regressor
model_knn = KNeighborsRegressor()
model_knn.fit(X_train, Y_train.values.ravel())  # .values.ravel() to flatten Y_train
score_knn = model_knn.score(X_test, Y_test)
print(f"KNN Regressor Score: {score_knn}")

# SVR Regressor
model_svr = SVR()
model_svr.fit(X_train, Y_train.values.ravel())
score_svr = model_svr.score(X_test, Y_test)
print(f"SVR Regressor Score: {score_svr}")

# Decision Tree Regressor
model_dtr = DecisionTreeRegressor()
model_dtr.fit(X_train, Y_train)
score_dtr = model_dtr.score(X_test, Y_test)
print(f"Decision Tree Regressor Score: {score_dtr}")

# Bagging Regressor (using Decision Tree as base estimator)
model_bagging = BaggingRegressor(estimator=DecisionTreeRegressor())
model_bagging.fit(X_train, Y_train.values.ravel())
score_bagging = model_bagging.score(X_test, Y_test)
print(f"Bagging Regressor Score: {score_bagging}")

# Random Forest Regressor
model_rfr = RandomForestRegressor()
model_rfr.fit(X_train, Y_train.values.ravel())
score_rfr = model_rfr.score(X_test, Y_test)
print(f"Random Forest Regressor Score: {score_rfr}")
# Out:
# KNN Regressor Score: 0.023612418452895745
# SVR Regressor Score: -0.10582207976851388
# Decision Tree Regressor Score: 0.4810841792080547
# Bagging Regressor Score: 0.6989476726088792
# Random Forest Regressor Score: 0.7111002836877869

# %%
model_knn= KNeighborsRegressor()
model_knn.fit(X_train,Y_train.values.ravel())
score_knn=model_knn.score(X_test,Y_test)
score_knn_train=model_knn.score(X_train,Y_train)
print(f"KNN Regressor Score Test: {score_knn}")
print(f"KNN Regressor Train Score: {score_knn_train}")
# Out:
# KNN Regressor Score Test: 0.023612418452895745
# KNN Regressor Train Score: 0.3473777209826696

# %%
model_svr=SVR()
model_svr.fit(X_train,Y_train.values.ravel())
score_svr=model_svr.score(X_test,Y_test)
score_svr_train=model_svr.score(X_train,Y_train)
print(f"SVR Regressor Test Score: {score_svr}")
print(f"SVR Regressor Train Score: {score_svr_train}")
# Out:
# SVR Regressor Test Score: -0.10582207976851388
# SVR Regressor Train Score: -0.10582975147813745

# %%
model_dtr=DecisionTreeRegressor()
model_dtr.fit(X_train,Y_train)
score_dtr=model_dtr.score(X_test,Y_test)
print(f"Decision Tree Regressor Score: {score_dtr}")
# Out:
# Decision Tree Regressor Score: 0.5039543965779827

# %%
from sklearn.ensemble import BaggingRegressor
model_bagging=BaggingRegressor(estimator=DecisionTreeRegressor())
model_bagging.fit(X_train,Y_train.values.ravel())
score_bagging=model_bagging.score(X_test,Y_test)
print(f"Bagging Regressor Score: {score_bagging}")
# Out:
# Bagging Regressor Score: 0.6741516551265618

# %%
model_rfr=RandomForestRegressor()
model_rfr.fit(X_train,Y_train.values.ravel())
score_rfr=model_rfr.score(X_test,Y_test)
score_rfr_train=model_rfr.score(X_train,Y_train)
print(f"Random Forest Regressor Test Score: {score_rfr}")
print(f"Random Forest Regressor Train Score: {score_rfr_train}")
# Out:
# Random Forest Regressor Test Score: 0.7129235312719331
# Random Forest Regressor Train Score: 0.9574194621798682

# %%
# prompt: control the overfitting and then share the score for randomforestRegressor

# The provided code already calculates the score for RandomForestRegressor.
# To control overfitting in Random Forest, you can adjust hyperparameters like:
# - n_estimators: The number of trees in the forest. Increasing this can help, but too many might lead to diminishing returns.
# - max_depth: The maximum depth of each tree. Limiting depth can prevent the model from becoming too complex.
# - min_samples_split: The minimum number of samples required to split an internal node.
# - min_samples_leaf: The minimum number of samples required to be at a leaf node.
# - max_features: The number of features to consider when looking for the best split.

# Let's train another Random Forest model with some hyperparameters to potentially control overfitting.
# Note: The best hyperparameter values depend on your specific dataset. This is just an example.

model_rfr_tuned = RandomForestRegressor(n_estimators=100, max_depth=10, random_state=42)
model_rfr_tuned.fit(X_train, Y_train.values.ravel())

score_rfr_tuned = model_rfr_tuned.score(X_test, Y_test)
score_rfr_tuned_train = model_rfr_tuned.score(X_train, Y_train)

print(f"Tuned Random Forest Regressor Test Score: {score_rfr_tuned}")
print(f"Tuned Random Forest Regressor Train Score: {score_rfr_tuned_train}")

# You can compare the train and test scores of the original and tuned models
# A large difference between train and test scores indicates overfitting.
# Ideally, you want both scores to be high and close to each other.
# Out:
# Tuned Random Forest Regressor Test Score: 0.7092068833861367
# Tuned Random Forest Regressor Train Score: 0.8541890007269735
